# %% [markdown]
# # Scalend Bank Data Analysis
#
# ## The aim is to build a model to classify newly added samples.

# %% [markdown]
# #### This data includes 17 columns out of which 7 features have more have 70% of missing data. I have used several methods to predict the missing data and have replaced it with the predicted classes.
#
# ###### Below I have imported libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %% [markdown]
# _The data is extracted from the excel file and converted into data frame using pandas._

# %%
data1 = pd.read_excel('F:\Machine Learning\Projects\Scalend\sample_data_test.xlsx',sep='\t')
data = pd.DataFrame(data1)
data.columns = ['cid_no','channel_id','transaction_id','transaction_datetime','transaction_amount','product','service_category','transaction_location','transaction_type','customer_type','sex','date_of_birth','educational_status','income','minor','marital_status','dependents']
data
# Out:
#         cid_no channel_id    transaction_id transaction_datetime  \
# 0     A0AA2953       ATM1  033ISAL171174163  2017-04-27 13:22:00
# 1     A2735A56       ATM1  033DBLC171091109  2017-04-20 03:56:00
# 2     A2735A56     Teller  071CHDP171090510  2017-04-19 00:00:00
# 3     A070599A        ATM  056CHDP171140032  2017-04-24 00:00:00
# 4     A06A3745       ATM1  045CHDP171140022  2017-04-24 00:00:00
# 5     A2866073       ATM1  008CHDP171030503  2017-04-13 00:00:00
# 6     A2889968       ATM2  033DCRD171150139  2017-04-25 12:46:00
# 7     A2907254       ATM2  072CHDP170990024  2017-04-09 00:00:00
# 8     A27A7299       ATM1  004CHDP170980010  2017-04-08 00:00:00
# 9     A27A7299       ATM1  004CHDP170980009  2017-04-08 00:00:00
# 10    A2880869        ATM  043CHDP170940003  2017-04-04 00:00:00
# 11    A2926537       ATM1  008CHDP170960010  2017-04-06 00:00:00
# 12    A053A344       ATM2  033ISAL171141064  2017-04-24 11:58:00
# 13    A03A9857       ATM1  033IWRT171150508  2017-04-25 09:27:00
# 14    A0002620       ATM1  020CHWL171150011  2017-04-25 00:00:00
# 15    A2574504        ATM  022CHDP171200008  2017-04-30 00:00:00
# 16    A2574504        ATM  010CHDP171190010  2017-04-29 00:00:00
# 17    A2574504     Teller  022CHDP171160519  2017-04-26 00:00:00
# 18    A2574504       ATM1  045CHDP171150009  2017-04-25 00:00:00
# 19    A2574504       ATM2  017CHDP171140050  2017-04-24 00:00:00
# 20    A2574504       ATM2  022CHDP171130057  2017-04-23 00:00:00
# 21    A2574504       ATM1  022CHDP171080043  2017-04-18 00:00:00
# 22    A2574504       ATM1  022CHDP171080525  2017-04-18 00:00:00
# 23    A2574504       ATM1  022CHDP170910564  2017-04-01 00:00:00
# 24    A2900365        ATM  014CHDP171140016  2017-04-24 00:00:00
# 25    A0063037     Teller  033IWRT171000200  2017-04-10 08:47:00
# 26    A0A00623       ATM1  033CARD170912223  2017-04-01 13:10:00
# 27    A0A00623       ATM1  071CHWL170910023  2017-04-01 00:00:00
# 28    A0A00623       ATM1  004CHWL170910514  2017-04-01 00:00:00
# 29    A2432A25       ATM1  033IWRT171080882  2017-04-18 14:51:00
# ...        ...        ...               ...                  ...
# 2623  A0A75266       ATM1  004CHDP170990530  2017-04-09 00:00:00
# 2624  A2579398     Teller  071CHDP171170023  2017-04-27 00:00:00
# 2625  A2900690       ATM2  007CHDP170950033  2017-04-05 00:00:00
# 2626  A0664285       ATM1  033ISAL171140694  2017-04-24 11:42:00
# 2627  A2854028       ATM2  008CHDP171130002  2017-04-23 00:00:00
# 2628  A2854028       ATM1  008CHDP171050006  2017-04-15 00:00:00
# 2629  A2854028       ATM1  008CHDP170950003  2017-04-05 00:00:00
# 2630  A2883924       ATM1  012CHDP170960508  2017-04-06 00:00:00
# 2631  A2866233       ATM1  008CHDP171070005  2017-04-17 00:00:00
# 2632  A2866233       ATM1  008CHDP170950018  2017-04-05 00:00:00
# 2633  A0A66A3A     Teller  033ISAL171167462  2017-04-26 11:16:00
# 2634  A0232343       ATM1  033IWCF171091204  2017-04-19 16:50:00
# 2635  A079268A       ATM2  014CHDP171190033  2017-04-29 00:00:00
# 2636  A079268A       ATM1  014CHDP171080032  2017-04-18 00:00:00
# 2637  A25A0989       ATM1  033CARD171172180  2017-04-27 17:03:00
# 2638  A25A0989       ATM1  033ICLB171173052  2017-04-27 11:34:00
# 2639  A25A0989       ATM1  033IWRT171152078  2017-04-25 17:12:00
# 2640  A0A556AA       ATM2  033ICLB171022815  2017-04-12 13:19:00
# 2641  A2926075        ATM  046CHDP171050507  2017-04-15 00:00:00
# 2642  A0AA5637       ATM1  033ICLB171084974  2017-04-18 15:09:00
# 2643  A0229004       ATM2  014CHWL170960003  2017-04-05 00:00:00
# 2644  A0A75266       ATM1  053CHDP171100005  2017-04-20 00:00:00
# 2645  A0080996        ATM  017CHDP171090024  2017-04-19 00:00:00
# 2646  A2547689       ATM1  043CHDP171090007  2017-04-19 00:00:00
# 2647  A2547689       ATM1  043CHDP171020003  2017-04-12 00:00:00
# 2648  A2547689     Teller  043CHDP170990506  2017-04-09 00:00:00
# 2649  A2547689        ATM  043CHDP170920502  2017-04-02 00:00:00
# 2650  A2787497       ATM1  014CHDP171140013  2017-04-24 00:00:00
# 2651  A2827650        ATM  014CHDP170990010  2017-04-09 00:00:00
# 2652  A0337598        ATM  033DBLC171200725  2017-04-30 12:12:00
#
#       transaction_amount  product service_category  transaction_location  \
# 0              209232.75      NaN       REMITTANCE                    19
# 1              275000.00      NaN       REMITTANCE                     3
# 2              240000.00      NaN     CASH DEPOSIT                     3
# 3              650000.00      NaN     CASH DEPOSIT                    45
# 4              300000.00      NaN     CASH DEPOSIT                    14
# 5              916500.00      NaN     CASH DEPOSIT                     8
# 6              256050.00      NaN       REMITTANCE                    71
# 7              992515.00      NaN     CASH DEPOSIT                    47
# 8              386000.00      NaN     CASH DEPOSIT                    91
# 9              900000.00      NaN     CASH DEPOSIT                    91
# 10            1800000.00      NaN     CASH DEPOSIT                    91
# 11             313530.00      NaN     CASH DEPOSIT                    91
# 12             227287.01      NaN       REMITTANCE                    12
# 13             253317.00      NaN       REMITTANCE                    17
# 14             700000.00      NaN  CASH WITHDRAWAL                    15
# 15             232000.00      NaN     CASH DEPOSIT                    73
# 16             250000.00      NaN     CASH DEPOSIT                    73
# 17             330000.00      NaN     CASH DEPOSIT                    73
# 18             600000.00      NaN     CASH DEPOSIT                    73
# 19            1000000.00      NaN     CASH DEPOSIT                    73
# 20             550000.00      NaN     CASH DEPOSIT                    73
# 21             298000.00      NaN     CASH DEPOSIT                    73
# 22             300000.00      NaN     CASH DEPOSIT                    73
# 23             400000.00      NaN     CASH DEPOSIT                    73
# 24             395000.00      NaN     CASH DEPOSIT                    24
# 25             294000.00      NaN       REMITTANCE                    24
# 26             860000.00      NaN       REMITTANCE                     3
# 27             300000.00      NaN  CASH WITHDRAWAL                     3
# 28             300000.00      NaN  CASH WITHDRAWAL                     3
# 29             300000.00      NaN       REMITTANCE                     3
# ...                  ...      ...              ...                   ...
# 2623           250000.00      NaN     CASH DEPOSIT                    17
# 2624           900000.00      NaN     CASH DEPOSIT                    82
# 2625           300000.00      NaN     CASH DEPOSIT                    91
# 2626           284815.02      NaN       REMITTANCE                     3
# 2627           400000.00      NaN     CASH DEPOSIT                     8
# 2628           919000.00      NaN     CASH DEPOSIT                     8
# 2629          1000600.00      NaN     CASH DEPOSIT                     8
# 2630           259000.00      NaN     CASH DEPOSIT                    12
# 2631          2674550.00      NaN     CASH DEPOSIT                    91
# 2632          1579780.00      NaN     CASH DEPOSIT                    91
# 2633           246208.00      NaN       REMITTANCE                    17
# 2634           338983.05      NaN       REMITTANCE                    25
# 2635           236255.00      NaN     CASH DEPOSIT                    14
# 2636           242880.00      NaN     CASH DEPOSIT                    14
# 2637          4735000.00      NaN       REMITTANCE                    45
# 2638           735000.00      NaN       REMITTANCE                    45
# 2639          3700000.00      NaN       REMITTANCE                    45
# 2640           425882.67      NaN       REMITTANCE                    13
# 2641           400000.00      NaN     CASH DEPOSIT                     4
# 2642           374123.58      NaN       REMITTANCE                    24
# 2643           466000.00      NaN  CASH WITHDRAWAL                    15
# 2644           362500.00      NaN     CASH DEPOSIT                    17
# 2645           250000.00      NaN     CASH DEPOSIT                    23
# 2646          1250000.00      NaN     CASH DEPOSIT                    17
# 2647           970000.00      NaN     CASH DEPOSIT                    17
# 2648          1190000.00      NaN     CASH DEPOSIT                    17
# 2649          1030000.00      NaN     CASH DEPOSIT                    17
# 2650           304900.00      NaN     CASH DEPOSIT                    91
# 2651          1006000.00      NaN     CASH DEPOSIT                    91
# 2652          1000000.00      NaN       REMITTANCE                    45
#
#      transaction_type customer_type  sex        date_of_birth  \
# 0           FINANCIAL             I    M  1963-08-06 00:00:00
# 1           FINANCIAL             I    M  1977-01-26 00:00:00
# 2           FINANCIAL             I    M  1977-01-26 00:00:00
# 3           FINANCIAL             C  NaN                    ~
# 4           FINANCIAL             C  NaN                    ~
# 5           FINANCIAL             C  NaN                    ~
# 6           FINANCIAL             I    M  1968-09-28 00:00:00
# 7           FINANCIAL             C  NaN                    ~
# 8           FINANCIAL             C  NaN                    ~
# 9           FINANCIAL             C  NaN                    ~
# 10          FINANCIAL             C  NaN                    ~
# 11          FINANCIAL             I    M  1968-07-05 00:00:00
# 12          FINANCIAL             I    M  1966-06-11 00:00:00
# 13          FINANCIAL             I    M  1965-08-01 00:00:00
# 14          FINANCIAL             I    M  1950-01-01 00:00:00
# 15          FINANCIAL             C  NaN                    ~
# 16          FINANCIAL             C  NaN                    ~
# 17          FINANCIAL             C  NaN                    ~
# 18          FINANCIAL             C  NaN                    ~
# 19          FINANCIAL             C  NaN                    ~
# 20          FINANCIAL             C  NaN                    ~
# 21          FINANCIAL             C  NaN                    ~
# 22          FINANCIAL             C  NaN                    ~
# 23          FINANCIAL             C  NaN                    ~
# 24          FINANCIAL             I    M  1959-03-21 00:00:00
# 25          FINANCIAL             I    M  1967-10-27 00:00:00
# 26          FINANCIAL             I    M  1972-10-14 00:00:00
# 27          FINANCIAL             I    M  1972-10-14 00:00:00
# 28          FINANCIAL             I    M  1972-10-14 00:00:00
# 29          FINANCIAL             I    M  1974-03-23 00:00:00
# ...               ...           ...  ...                  ...
# 2623        FINANCIAL             C  NaN                  NaN
# 2624        FINANCIAL             C  NaN                  NaN
# 2625        FINANCIAL             C  NaN                  NaN
# 2626        FINANCIAL             I    F  1972-01-23 00:00:00
# 2627        FINANCIAL             C  NaN                  NaN
# 2628        FINANCIAL             C  NaN                  NaN
# 2629        FINANCIAL             C  NaN                  NaN
# 2630        FINANCIAL             C  NaN                  NaN
# 2631        FINANCIAL             C  NaN                  NaN
# 2632        FINANCIAL             C  NaN                  NaN
# 2633        FINANCIAL             I    M  1965-10-07 00:00:00
# 2634        FINANCIAL             I    M  1954-10-01 00:00:00
# 2635        FINANCIAL             C  NaN                  NaN
# 2636        FINANCIAL             C  NaN                  NaN
# 2637        FINANCIAL             I    M  1978-04-02 00:00:00
# 2638        FINANCIAL             I    M  1978-04-02 00:00:00
# 2639        FINANCIAL             I    M  1978-04-02 00:00:00
# 2640        FINANCIAL             I    M  1944-12-27 00:00:00
# 2641        FINANCIAL             I    M  1960-09-28 00:00:00
# 2642        FINANCIAL             I    F  1976-08-26 00:00:00
# 2643        FINANCIAL             I    M  1951-08-12 00:00:00
# 2644        FINANCIAL             C  NaN                  NaN
# 2645        FINANCIAL             C  NaN                  NaN
# 2646        FINANCIAL             C  NaN                  NaN
# 2647        FINANCIAL             C  NaN                  NaN
# 2648        FINANCIAL             C  NaN                  NaN
# 2649        FINANCIAL             C  NaN                  NaN
# 2650        FINANCIAL             C  NaN                  NaN
# 2651        FINANCIAL             C  NaN                  NaN
# 2652        FINANCIAL             I    M  1961-10-21 00:00:00
#
#      educational_status      income minor marital_status  dependents
# 0           NON STUDENT      SALARY     N              M           8
# 1           NON STUDENT    BUSINESS     N              M           2
# 2           NON STUDENT    BUSINESS     N              M           2
# 3                   NaN         NaN   NaN            NaN           0
# 4                   NaN         NaN     N            NaN           0
# 5                   NaN         NaN     N            NaN           0
# 6           NON STUDENT      SALARY     N              M           2
# 7                   NaN         NaN   NaN            NaN           0
# 8                   NaN         NaN     N            NaN           0
# 9                   NaN         NaN     N            NaN           0
# 10                  NaN         NaN   NaN            NaN           0
# 11          NON STUDENT    BUSINESS     N              M           1
# 12          NON STUDENT      SALARY     N              M           0
# 13          NON STUDENT      SALARY     N              M           3
# 14          NON STUDENT      SALARY     N              M           0
# 15                  NaN         NaN   NaN            NaN           0
# 16                  NaN         NaN   NaN            NaN           0
# 17                  NaN         NaN   NaN            NaN           0
# 18                  NaN         NaN   NaN            NaN           0
# 19                  NaN         NaN   NaN            NaN           0
# 20                  NaN         NaN   NaN            NaN           0
# 21                  NaN         NaN   NaN            NaN           0
# 22                  NaN         NaN   NaN            NaN           0
# 23                  NaN         NaN   NaN            NaN           0
# 24                  NaN    BUSINESS     N              M           0
# 25          NON STUDENT      SALARY     N              S           0
# 26          NON STUDENT      RENTAL     N              M           3
# 27          NON STUDENT      RENTAL     N              M           3
# 28          NON STUDENT      RENTAL     N              M           3
# 29          NON STUDENT  INVESTMENT     N            NaN           0
# ...                 ...         ...   ...            ...         ...
# 2623                NaN         NaN     N            NaN           0
# 2624                NaN         NaN   NaN            NaN           0
# 2625                NaN         NaN     N            NaN           0
# 2626        NON STUDENT      SALARY     N              M           3
# 2627                NaN         NaN     N            NaN           0
# 2628                NaN         NaN     N            NaN           0
# 2629                NaN         NaN     N            NaN           0
# 2630                NaN         NaN   NaN            NaN           0
# 2631                NaN         NaN   NaN            NaN           0
# 2632                NaN         NaN   NaN            NaN           0
# 2633        NON STUDENT      SALARY     N              M           4
# 2634        NON STUDENT      SALARY     N              M           0
# 2635                NaN         NaN     N            NaN           0
# 2636                NaN         NaN     N            NaN           0
# 2637        NON STUDENT    BUSINESS     N              M           3
# 2638        NON STUDENT    BUSINESS     N              M           3
# 2639        NON STUDENT    BUSINESS     N              M           3
# 2640        NON STUDENT      SALARY     N              M           0
# 2641        NON STUDENT      SALARY     N              M           2
# 2642        NON STUDENT      SALARY     N              S           0
# 2643        NON STUDENT    BUSINESS     N              M           2
# 2644                NaN         NaN     N            NaN           0
# 2645                NaN         NaN     N            NaN           0
# 2646                NaN         NaN   NaN            NaN           0
# 2647                NaN         NaN   NaN            NaN           0
# 2648                NaN         NaN   NaN            NaN           0
# 2649                NaN         NaN   NaN            NaN           0
# 2650                NaN         NaN   NaN            NaN           0
# 2651                NaN         NaN   NaN            NaN           0
# 2652        NON STUDENT      SALARY     N              M           0
#
# [2653 rows x 17 columns]

# %% [markdown]
# #### This indicated that the data consists of 2653 samples and 17 features.

# %%
data.shape
# Out:
# (2653, 17)

# %% [markdown]
# _Calculating the percentage of the missing values in each of the features_

# %%
num = data.isnull().sum()
total = len(data)
print num/total
# Out:
# cid_no                  0.000000
# channel_id              0.000000
# transaction_id          0.000000
# transaction_datetime    0.000000
# transaction_amount      0.000000
# product                 1.000000
# service_category        0.000000
# transaction_location    0.000000
# transaction_type        0.000000
# customer_type           0.000000
# sex                     0.692424
# date_of_birth           0.706747
# educational_status      0.732378
# income                  0.759894
# minor                   0.387109
# marital_status          0.725594
# dependents              0.000000
# dtype: float64

# %% [markdown]
# _Removing the feature called 'product' because it has 0 data and consists of only missing values which is useless in our dataset.
# Creating a data set which consists on zero missing data to train and predcit the missing values._

# %%
data_extraction = data.drop('product',1)
data_no_nulls = data_extraction.dropna()
data_no_nulls = data_no_nulls.reset_index()

# %% [markdown]
# _Transforming the data into a dataframe where the catagorical values are converted using one hot-encoding method so that it consists of only numeric data_

# %% [markdown]
# _Predicting the missing values using a Logistic regression because the feature 'transaction__amount' ranges till 600000 and using logistic function will scale the values and variance will be reduced._

# %%
train_data = data_no_nulls[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
train = pd.get_dummies(train_data)

X_sex = train
y_sex = data_no_nulls['sex']
x_train,x_test,y_train,y_test = train_test_split(X_sex,y_sex,test_size = 0.2)

test_data = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
logreg = LogisticRegression()
logreg.fit(x_train,y_train)

print logreg.score(x_test,y_test)
# Out:
# 0.834782608696

# %% [markdown]
# ## Using Logistic regression to predict the missing values

# %% [markdown]
# _The feature sex consists of two categories 'M' and 'F' and the data is predicted. The main data's missing values is then replaced with the predicted classes._

# %%
#sex predcition

train_data = data_no_nulls[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
train_data_x = pd.get_dummies(train_data)
train_data_y = (data_no_nulls[['sex']])

test_data = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
test_data_x = pd.get_dummies(test_data)
logreg.fit(train_data_x,train_data_y)
sex_predicted = pd.DataFrame()
sex_predicted['sex1'] = logreg.predict(test_data_x)
# Out:
# c:\python27\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# _Predicting the age of the customer so that this feature can be converted into another feature of continuous varaibles and can be used to build the model._

# %%
#predicting the age 

import datetime as datetime
dob = pd.DataFrame()
dob['dob'] = pd.to_datetime(data_no_nulls['date_of_birth'])
now = datetime.datetime.now()    
dob['age'] = (now - dob['dob'])/365.25
dob['age'] = dob['age'].astype('timedelta64[D]')

# %% [markdown]
# _Predicting if the particular cliet is minor or not_

# %%
#predicting minor or not

train_minor_x = train_data_x
train_minor_y = data_no_nulls['minor']

test_minor = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
test_minor = pd.get_dummies(test_minor)
logreg.fit(train_minor_x,train_minor_y)
minor_predicted = pd.DataFrame()
minor_predicted['minor1'] = logreg.predict(test_minor)

# %% [markdown]
# _Predicting the educational status_

# %%
#predicting educational status

train_edu_x = train_data_x
train_edu_y = data_no_nulls['educational_status']

test_edu = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
test_edu = pd.get_dummies(test_edu)
logreg.fit(train_edu_x,train_edu_y)
edu_predicted = pd.DataFrame()
edu_predicted['edu1'] = logreg.predict(test_edu)

# %% [markdown]
# _Predicting the income_

# %%
#predicting income

train_income_x = train_data_x
train_income_y = data_no_nulls['income']

test_income = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
test_income = pd.get_dummies(test_income)
logreg.fit(train_income_x,train_income_y)
income_predicted = pd.DataFrame()
income_predicted['income1'] = logreg.predict(test_income)

# %% [markdown]
# _Predicting the marital status_

# %%
#predicting marital_status 

train_marital_status_x = train_data_x
train_marital_status_y = data_no_nulls['marital_status']

test_marital_status = data[['channel_id','service_category','transaction_type','dependents','transaction_amount','transaction_location']]
test_marital_status = pd.get_dummies(test_marital_status)
logreg.fit(train_marital_status_x,train_marital_status_y)
marital_status_predicted = pd.DataFrame()
marital_status_predicted['marital_status1'] = logreg.predict(test_marital_status)

# %% [markdown]
# ## Replacing the predicted classes with the missing values

# %%
final_replaced = data_extraction
final_replaced.sex.fillna(sex_predicted.sex1, inplace=True)
final_replaced.minor.fillna(minor_predicted.minor1, inplace=True)
final_replaced.marital_status.fillna(marital_status_predicted.marital_status1, inplace=True)
final_replaced.income.fillna(income_predicted.income1, inplace=True)
final_replaced.educational_status.fillna(edu_predicted.edu1, inplace=True)
final_replaced.drop('date_of_birth',axis=1)
final_replaced.isnull().sum()
# Out:
# cid_no                     0
# channel_id                 0
# transaction_id             0
# transaction_datetime       0
# transaction_amount         0
# service_category           0
# transaction_location       0
# transaction_type           0
# customer_type              0
# sex                        0
# date_of_birth           1875
# educational_status         0
# income                     0
# minor                      0
# marital_status             0
# dependents                 0
# dtype: int64

# %% [markdown]
# ## Analysis of the data

# %% [markdown]
# _From the below graph we can make out that the ATM1 has been used highest by the customers. This feature provids more information compared to other channel ids_

# %%
sct = final_replaced[['channel_id','income','transaction_amount']]
sct.groupby('channel_id').size().plot(kind='bar')

plt.show()

# %% [markdown]
# _A Swarmplot showing the distribution of channel ids with the transaction amount. This indicates the co-relation with the above graph which tells us that ATM1 is important._

# %%
import seaborn as sns
color = sns.color_palette()
atm_vs_type = final_replaced[['channel_id','service_category']]
atm_vs_type_count = cust_atm_vs_type.groupby(['channel_id','service_category'])
atm_type = list(atm_vs_type_count['channel_id'])
service_type = list(atm_vs_type_count['service_category'])
plt.figure(figsize=(12,8))
sns.swarmplot(x= 'channel_id',y='transaction_amount', color = color[2],data=final_replaced)
plt.show()

# %% [markdown]
# _The below graph shows the service category of various types of transactions done. Salary displays the highest with Cash deposit transaction._

# %%
color_table = pd.crosstab(index=final_replaced['income'], columns=final_replaced['service_category'])
color_table.plot(kind="bar", figsize=(8,8),stacked=True)

# %% [markdown]
# _Below graph shows the ATM1 being used the highest in the last week of the month_

# %%
category_channel = final_replaced.channel_id
dttime = final_replaced.transaction_datetime
atm_vs_datetime = pd.DataFrame({'category_channel':category_channel,'dttime':dttime})
channel_cat = (atm_vs_datetime.reset_index().groupby(['dttime','category_channel'],as_index=False).count())

fig, ax = plt.subplots()
for key,data in channel_cat.groupby('category_channel'):
    data.plot(x='dttime',y='index',ax=ax,label=key)

# %% [markdown]
# # Classification using Clustering

# %% [markdown]
# _Using a dendogram to analyse the right number of clusters required for the clustering_

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(X , method= 'ward'))

# %%
import sklearn
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

import sklearn.metrics as sm
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# _Scaling the values using MinMax classifier because of high variance caused by the feature 'transaction amount'_

# %%
train_all = final_replaced[['channel_id','transaction_amount','transaction_location','transaction_type','customer_type','sex','educational_status','income','minor','marital_status','dependents',]]
train_dummies = pd.get_dummies(train_all)
scaler = MinMaxScaler()

scaler.fit(train_dummies)
X = scaler.transform(train_dummies)

# %% [markdown]
# _KMeans clustering with cluster size =10._

# %%
clustering = KMeans(n_clusters=10 , random_state=5)
clustering.fit_predict(X)
# Out:
# array([1, 6, 6, ..., 2, 4, 7])

# %% [markdown]
# _Plot showing the KMeans clustering._

# %%
color_theme = np.array(['darkgray','lightsalmon','powerblue','green','black'])
plt.scatter(y=final_replaced.transaction_location,x=clustering.labels_)

# %% [markdown]
# ### Clustering using Agglomerative Clustering
#
# _with cluster size = 10_

# %%
from sklearn.cluster import AgglomerativeClustering
hc  = AgglomerativeClustering(n_clusters = 10 , affinity = 'euclidean',linkage = 'ward')
y_hc = hc.fit_predict(X)

plt.scatter(X[y_hc == 0,0],X[y_hc ==0,1],s=100 , c = 'red',label ='Cluster1')
plt.scatter(X[y_hc == 1,0],X[y_hc ==1,1],s=100 , c = 'blue',label ='Cluster2')
plt.scatter(X[y_hc == 2,0],X[y_hc ==2,1],s=100 , c = 'green',label ='Cluster3')

# %% [markdown]
# ## Random forest Classification
#
# _with number of decisiontrees = 500_

# %%
randomforest = RandomForestClassifier(n_estimators=500)
X_train_rc , X_test_rc , y_train_rc , y_test_rc = train_test_split(X,final_replaced.service_category,test_size=0.2 , random_state = 5)
randomforest.fit(X_train_rc,y_train_rc)
rc_predicted = randomforest.predict(X_test_rc)
randomforest.score(X_test_rc , y_test_rc)
# Out:
# 0.93785310734463279

# %%
confusion_matrix(rc_predicted,y_test_rc)
# Out:
# array([[403,   0,   7],
#        [  0,   3,   8],
#        [  9,   9,  92]], dtype=int64)

# %%
print classification_report(y_test_rc,rc_predicted)
# Out:
#                  precision    recall  f1-score   support
#
#    CASH DEPOSIT       0.98      0.98      0.98       412
# CASH WITHDRAWAL       0.27      0.25      0.26        12
#      REMITTANCE       0.84      0.86      0.85       107
#
#     avg / total       0.94      0.94      0.94       531

# %% [markdown]
# ## Support vector machine classifier
#
# _with kernal = linear and cost function = 0.5_

# %%
svm = SVC(kernel='linear',C=0.5)
a = svm.fit(X_train_rc,y_train_rc)
svm_predicted = svm.predict(X_test_rc)
svm.score(X_test_rc , y_test_rc)
# Out:
# 0.94161958568738224

# %%
confusion_matrix(svm_predicted,y_test_rc)
# Out:
# array([[394,   0,   1],
#        [  0,   0,   0],
#        [ 18,  12, 106]], dtype=int64)

# %%
print classification_report(y_test_rc,svm_predicted)
# Out:
#                  precision    recall  f1-score   support
#
#    CASH DEPOSIT       1.00      0.96      0.98       412
# CASH WITHDRAWAL       0.00      0.00      0.00        12
#      REMITTANCE       0.78      0.99      0.87       107
#
#     avg / total       0.93      0.94      0.93       531
